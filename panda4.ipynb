# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\Bishal Majee\Desktop\panda\customer_data.csv')
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0          01-01-2019          151200  Female  19.0         Single
# 1          02-01-2019          151201    Male  49.0         Single
# 2          03-01-2019          151202    Male  63.0        Married
# 3          04-01-2019          151203     NaN  18.0         Single
# 4          05-01-2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507       12-11-2025          153695  Female  57.0         Single
# 2508       13-11-2025          153696  Female  36.0        Married
# 2509       14-11-2025          153697    Male  22.0         Single
# 2510       15-11-2025          153698     NaN  44.0         Single
# 2511       16-11-2025          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
df.describe().T
# Out:
#                  count           mean         std        min          25%  \
# Transaction_ID  2512.0  152443.931131  724.580482  151200.00  151815.7500
# Age             2470.0      46.637652   18.186277      15.00      32.0000
# Referal         2357.0       0.652100    0.476405       0.00       0.0000
# Amount_spent    2270.0    1418.422577  878.507451       2.09     678.1925
#
#                        50%          75%        max
# Transaction_ID  152443.500  153071.2500  153699.00
# Age                 47.000      62.0000      78.00
# Referal              1.000       1.0000       1.00
# Amount_spent      1341.435    2038.1025    2999.98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2357 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
mean=df['Age'].mean()
mean
# Out:
# 46.63765182186235

# %%
median=df['Age'].median()
median
# Out:
# 47.0

# %%
std=df['Age'].std()
std
# Out:
# 18.186276792698028

# %%
mode=df['Age'].mode()
mode
# Out:
# 0    54.0
# Name: Age, dtype: float64

# %%
min=df['Age'].min()
print(min)
max=df['Age'].max()
print(max)
# Out:
# 15.0
# 78.0

# %%
corr=df['Age'].corr(df['Amount_spent'])
corr
# Out:
# -0.023341736974259154

# %%
df['State_names'].nunique()
# Out:
# 50

# %%
df['State_names'].unique()
# Out:
# array(['Kansas', 'Illinois', 'New Mexico', 'Virginia', 'Connecticut',
#        'Hawaii', 'Florida', 'Vermont', 'California', 'Colorado', 'Iowa',
#        'South Carolina', 'New York', 'Maine', 'Maryland', 'Missouri',
#        'North Dakota', 'Ohio', 'Nebraska', 'Montana', 'Indiana',
#        'Wisconsin', 'Alabama', 'Arkansas', 'Pennsylvania',
#        'New Hampshire', 'Washington', 'Texas', 'Kentucky',
#        'Massachusetts', 'Wyoming', 'Louisiana', 'North Carolina',
#        'Rhode Island', 'West Virginia', 'Tennessee', 'Oregon', 'Alaska',
#        'Oklahoma', 'Nevada', 'New Jersey', 'Michigan', 'Utah', 'Arizona',
#        'South Dakota', 'Georgia', 'Idaho', 'Mississippi', 'Minnesota',
#        'Delaware'], dtype=object)

# %%
df['Gender'].value_counts(normalize=True)#shows the percentage
# Out:
# Gender
# Female    0.545894
# Male      0.454106
# Name: proportion, dtype: float64

# %%
df.sort_values(by=["State_names"]).head(5)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 617        09-09-2020          151805    Male  43.0        Married
# 1856       31-01-2024          153044  Female  18.0        Married
# 2443       09-09-2025          153631    Male  60.0        Married
# 2441       07-09-2025          153629    Male  18.0         Single
# 1023       20-10-2021          152211  Female  30.0        Married
#
#      State_names   Segment Employees_status Payment_method  Referal  \
# 617      Alabama    Silver        Employees         PayPal      1.0
# 1856     Alabama    Silver          workers         PayPal      NaN
# 2443     Alabama  Platinum        Employees         PayPal      1.0
# 2441     Alabama  Platinum        Employees           Card      0.0
# 1023     Alabama  Platinum     Unemployment          Other      0.0
#
#       Amount_spent
# 617          87.88
# 1856       2091.73
# 2443           NaN
# 2441        289.85
# 1023           NaN

# %%
df.sort_values(by=["Amount_spent"],ascending=False).head(5)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 17         18-01-2019          151217  Female  77.0        Married
# 485        30-04-2020          151673    Male  65.0        Married
# 2279       29-03-2025          153467  Female  78.0         Single
# 589        12-08-2020          151777    Male  51.0         Single
# 743        13-01-2021          151931    Male  44.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 17        New Mexico  Platinum          workers           Card      0.0
# 485          Arizona      Gold    self-employed         PayPal      1.0
# 2279         Arizona    Silver        Employees         PayPal      1.0
# 589   North Carolina   Missing        Employees         PayPal      1.0
# 743         Illinois     Basic        Employees           Card      1.0
#
#       Amount_spent
# 17         2999.98
# 485        2998.62
# 2279       2997.21
# 589        2997.15
# 743        2996.82

# %%
df.nlargest(5,'Amount_spent')
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 17         18-01-2019          151217  Female  77.0        Married
# 485        30-04-2020          151673    Male  65.0        Married
# 2279       29-03-2025          153467  Female  78.0         Single
# 589        12-08-2020          151777    Male  51.0         Single
# 743        13-01-2021          151931    Male  44.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 17        New Mexico  Platinum          workers           Card      0.0
# 485          Arizona      Gold    self-employed         PayPal      1.0
# 2279         Arizona    Silver        Employees         PayPal      1.0
# 589   North Carolina   Missing        Employees         PayPal      1.0
# 743         Illinois     Basic        Employees           Card      1.0
#
#       Amount_spent
# 17         2999.98
# 485        2998.62
# 2279       2997.21
# 589        2997.15
# 743        2996.82

# %%
df.nsmallest(5,'Amount_spent')
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2468       04-10-2025          153656  Female  73.0        Married
# 568        22-07-2020          151756    Male  46.0         Single
# 2401       29-07-2025          153589  Female  60.0         Single
# 962        20-08-2021          152150  Female  56.0        Married
# 860        10-05-2021          152048    Male  26.0         Single
#
#          State_names Segment Employees_status Payment_method  Referal  \
# 2468        Michigan    Gold        Employees         PayPal      1.0
# 568   South Carolina    Gold          workers         PayPal      0.0
# 2401        Maryland  Silver        Employees         PayPal      1.0
# 962           Nevada   Basic          workers          Other      1.0
# 860         Maryland  Silver     Unemployment         PayPal      1.0
#
#       Amount_spent
# 2468          2.09
# 568           2.16
# 2401          2.84
# 962           5.31
# 860           5.55

# %%
paypal=df[df['Payment_method']=="PayPal"]
paypal
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2          03-01-2019          151202    Male  63.0        Married
# 5          06-01-2019          151205    Male  71.0         Single
# 6          07-01-2019          151206  Female  34.0        Married
# 7          08-01-2019          151207    Male  37.0        Married
# 10         11-01-2019          151210  Female  56.0        Married
# ...               ...             ...     ...   ...            ...
# 2503       08-11-2025          153691    Male  67.0         Single
# 2508       13-11-2025          153696  Female  36.0        Married
# 2509       14-11-2025          153697    Male  22.0         Single
# 2510       15-11-2025          153698     NaN  44.0         Single
# 2511       16-11-2025          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2         New Mexico     Basic          workers         PayPal      1.0
# ...

# %%
df[df['Payment_method']=='PayPal'].nlargest(5, 'Amount_spent')
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 485        30-04-2020          151673    Male  65.0        Married
# 2279       29-03-2025          153467  Female  78.0         Single
# 589        12-08-2020          151777    Male  51.0         Single
# 101        12-04-2019          151296  Female  33.0        Married
# 1177       23-03-2022          152365  Female  30.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 485          Arizona      Gold    self-employed         PayPal      1.0
# 2279         Arizona    Silver        Employees         PayPal      1.0
# 589   North Carolina   Missing        Employees         PayPal      1.0
# 101         Virginia  Platinum        Employees         PayPal      0.0
# 1177        Michigan     Basic    self-employed         PayPal      0.0
#
#       Amount_spent
# 485        2998.62
# 2279       2997.21
# 589        2997.15
# 101        2989.33
# 1177       2985.70

# %%
import matplotlib.pyplot as plt
